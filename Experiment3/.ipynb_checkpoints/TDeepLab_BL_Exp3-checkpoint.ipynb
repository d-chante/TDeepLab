# %% [markdown]
# # DeepLab

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dropout, Activation, UpSampling2D
from tensorflow.keras.layers import AveragePooling2D, Conv2DTranspose, Concatenate, Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.image import resize, ResizeMethod
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from PIL import Image

import random
import os
import numpy as np
from numpy import load
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment3/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment3/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment3/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:0'

get_ipython().system('nvidia-smi')

'''
TRAINING DATA
'''
exp3_rgb_X_train = load(TRAIN_DIR + '/exp3_rgb_X_train_dl.npy')
exp3_ir_X_train = load(TRAIN_DIR + '/exp3_ir_X_train_dl.npy')
exp3_y_train = load(TRAIN_DIR + '/exp3_y_train_dl.npy')

'''
VALIDATION DATA
'''
exp3_rgb_X_val = load(VAL_DIR + '/exp3_rgb_X_val_dl.npy')
exp3_ir_X_val = load(VAL_DIR + '/exp3_ir_X_val_dl.npy')
exp3_y_val = load(VAL_DIR + '/exp3_y_val_dl.npy')

'''
TEST DATA
'''
exp3_rgb_X_test_a = load(TEST_DIR + '/exp3_rgb_X_test_a_dl.npy')
exp3_ir_X_test_a = load(TEST_DIR + '/exp3_ir_X_test_a_dl.npy')
exp3_y_test_a = load(TEST_DIR + '/exp3_y_test_a_dl.npy')

exp3_rgb_X_test_b = load(TEST_DIR + '/exp3_rgb_X_test_b_dl.npy')
exp3_ir_X_test_b = load(TEST_DIR + '/exp3_ir_X_test_b_dl.npy')
exp3_y_test_b = load(TEST_DIR + '/exp3_y_test_b_dl.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FREQUENCY-WEIGHTED INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', 7)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(7), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# 2023-10-19 01:45:40.805170: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Thu Oct 19 01:45:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   29C    P8     9W / 250W |      0MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Done

# %%
'''
COMBINE RGB/IR IMAGES
'''
def combine_rgb_ir(rgb_images, ir_images):
    combined_images = []
    
    for i in range(len(ir_images)):
        ir = np.dstack([ir_images[i]] * 3)
        rgb = np.asarray(rgb_images[i], dtype=np.uint8)

        comb = ir + rgb
        comb = Image.fromarray(comb)
        comb = comb.resize((572, 572))
        comb = np.asarray(comb)

        combined_images.append(comb)
    
    return np.array(combined_images)

exp3_comb_X_train = combine_rgb_ir(exp3_rgb_X_train, exp3_ir_X_train)
exp3_comb_X_val = combine_rgb_ir(exp3_rgb_X_val, exp3_ir_X_val)
exp3_comb_X_test_a = combine_rgb_ir(exp3_rgb_X_test_a, exp3_ir_X_test_a)
exp3_comb_X_test_b = combine_rgb_ir(exp3_rgb_X_test_b, exp3_ir_X_test_b)

# %%
'''
MODEL PARAMS
'''
INPUT_DIMS = (572, 572, 3)

BATCH_SIZE = 4
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

DROPOUT_RATE = 0.5

TRAINABLE_LAYERS = 300

LOSS_ = BinaryCrossentropy()
METRICS_ = [BinaryAccuracy()]

EXP3_FILENAME = "tdeeplab_bl_exp3_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done
# 2023-10-19 01:45:59.700202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:45:59.705287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:45:59.705529: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:45:59.707140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:45:59.707380: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:45:59.707583: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:46:00.470755: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:46:00.470983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:46:00.471172: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-19 01:46:00.471347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 23635 MB memory:  -> device: 0, name: Tesla P40, pci bus id: 0000:05:00.0, compute capability: 6.1

# %% [markdown]
# ### DeepLab Common

# %%
'''
Atrous Spatial Pyramid Pooling
'''
def ASPP(inputs):
    shape = inputs.shape

    y_pool = AveragePooling2D(pool_size=(shape[1], shape[2]), name='average_pooling')(inputs)
    y_pool = Conv2D(filters=256, kernel_size=1, padding='same', use_bias=False)(y_pool)
    y_pool = BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = Activation('relu', name=f'relu_1')(y_pool)
    y_pool = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y_pool)

    y_1 = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(inputs)
    y_1 = BatchNormalization()(y_1)
    y_1 = Activation('relu')(y_1)

    y_6 = Conv2D(filters=256, kernel_size=3, dilation_rate=6, padding='same', use_bias=False)(inputs)
    y_6 = BatchNormalization()(y_6)
    y_6 = Activation('relu')(y_6)

    y_12 = Conv2D(filters=256, kernel_size=3, dilation_rate=12, padding='same', use_bias=False)(inputs)
    y_12 = BatchNormalization()(y_12)
    y_12 = Activation('relu')(y_12)

    y_18 = Conv2D(filters=256, kernel_size=3, dilation_rate=18, padding='same', use_bias=False)(inputs)
    y_18 = BatchNormalization()(y_18)
    y_18 = Activation('relu')(y_18)

    y = Concatenate()([y_pool, y_1, y_6, y_12, y_18])

    y = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    return y

def DeepLab(shape):
    """ Inputs """
    inputs = Input(shape)
    
    """ Pre-trained ResNet101 """
    base_model = ResNet101(weights='imagenet', include_top=False, input_tensor=inputs)
    
    for layer in base_model.layers[:TRAINABLE_LAYERS]:
        layer.trainable = False
    for layer in base_model.layers[TRAINABLE_LAYERS:]:
        layer.trainable = True

    """ Pre-trained ResNet101 Output """
    image_features = base_model.get_layer('conv4_block23_out').output
    x_a = ASPP(image_features)
    x_a = UpSampling2D((4, 4), interpolation="bilinear")(x_a)

    """ Get low-level features """
    x_b = base_model.get_layer('conv2_block2_out').output
    x_b = Conv2D(filters=48, kernel_size=1, padding='same', use_bias=False)(x_b)
    x_b = BatchNormalization()(x_b)
    x_b = Activation('relu')(x_b)

    """ Spatial Pyramid Pooling (SPP) """
    # Apply different pooling sizes
    pool1 = GlobalAveragePooling2D()(x_a)
    pool2 = GlobalAveragePooling2D()(x_a)
    pool3 = GlobalAveragePooling2D()(x_a)

    # Concatenate pooled features
    spp_features = Concatenate()([pool1, pool2, pool3])

    # Reshape to match x_b's shape
    spp_features = tf.keras.layers.Reshape((1, 1, -1))(spp_features)
    spp_features = UpSampling2D((x_b.shape[1], x_b.shape[2]), interpolation="bilinear")(spp_features)

    x = Concatenate()([spp_features, x_b])

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)
    x = UpSampling2D((4, 4), interpolation="bilinear")(x)

    """ Outputs """
    x = Conv2D(7, (1, 1), name='output_layer')(x)
    x = Activation('softmax')(x)

    """ Model """
    model = Model(inputs=inputs, outputs=x)
    return model

'''
TRAIN
'''
def DeepLab_Train(model, X_train, y_train, X_val, y_val, weights_filename):
    
    try:
        with tf.device(gpu_p40):
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss=LOSS_, 
                metrics=METRICS_)
            
            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
            
            history = model.fit(
                X_train, y_train,
                validation_data=(X_val, y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
            
    except RuntimeError as e:
        print(e)

'''
SCORE
'''
def DeepLab_Score(model, weights_filename, metrics_filename, X_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            score = model.evaluate(X_test, y_test, batch_size=2, verbose=1)

    except RuntimeError as e:
        print(e)

    # Print and save the test metrics
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])

    with open(metrics_filename, "a") as f:
        f.write(f"\Test Loss: {score[0]}\n")
        f.write(f"\Test Accuracy: {score[1]}\n")
        
'''
PREDICT
'''
def DeepLab_Predict(model, X_rgb_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test], batch_size=BATCH_SIZE)
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def DeepLab_Display(X_rgb_test, y_test, y_pred):

    try:
        with tf.device(gpu_p40):
            fig, axes = plt.subplots(1, 3, figsize=(10, 6))
            n = random.randint(0, len(X_rgb_test)-1)
            cmap = plt.get_cmap('tab10', 7)
    
            axes[0].imshow(X_rgb_test[n])
            axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
            axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
            axes[0].set_title("RGB")
            axes[1].set_title("Annotation")
            axes[2].set_title("Predicted")
    
            for ax in axes.flatten():
                ax.axis("off")
        
            plt.tight_layout()
            plt.show()
            
    except RuntimeError as e:
        print(e)
'''
METRICS
'''
def DeepLab_Metrics(y_test, y_pred, metrics_filename):

    try:
        with tf.device(gpu_p40):
            y_pred_classes = np.argmax(y_pred, axis=-1)
            y_true_classes = np.argmax(y_test, axis=-1)
    
            num_classes=7

            iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
            pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
            mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
            fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)

            print(f"Mean IoU: {mean_iou}")
            print(f"Pixel accuracy: {pixel_acc}")
            print(f"Mean accuracy: {mean_acc}")
            print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
            with open(metrics_filename, "a") as f:
                f.write("\nIoU Values:\n")
                for i, iou_val in enumerate(iou_values):
                    f.write(f"Class {i}: {iou_val}\n")
                f.write(f"\nMean IoU: {mean_iou}\n")
                f.write(f"Pixel Accuracy: {pixel_acc}\n")
                f.write(f"Mean Accuracy: {mean_acc}\n")
                f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    except RuntimeError as e:
        print(e)

print("Done")
# Out:
# Done

# %%
'''
FILENAMES
'''
exp3_weights_filename = os.path.join(WEIGHTS_PATH, 'tdeeplab_bl_exp3.h5')
exp3_metrics_filename = os.path.join(METRICS_PATH, 'tdeeplab_bl_exp3.txt')

print("Done")
# Out:
# Done

# %%
'''
model
'''
try:
    with tf.device(gpu_p40):
        exp3_model = DeepLab(INPUT_DIMS)         
except RuntimeError as e:
    print(e)

print("Done")
# Out:
# Done

# %%
'''
TRAIN
'''
DeepLab_Train(
    exp3_model, exp3_comb_X_train, exp3_y_train, exp3_comb_X_val, exp3_y_val, exp3_weights_filename)

print("Done")
# Out:
# Epoch 1/1000
# 2023-10-19 01:46:29.894014: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-19 01:46:31.227273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-10-19 01:46:34.374448: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x1dc790b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-19 01:46:34.374511: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla P40, Compute Capability 6.1
# 2023-10-19 01:46:34.387095: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-19 01:46:34.586567: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 0.37605, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 59s - loss: 0.5322 - binary_accuracy: 0.8708 - val_loss: 0.3761 - val_binary_accuracy: 0.8739 - lr: 1.0000e-04 - 59s/epoch - 848ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.37605 to 0.35043, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.3328 - binary_accuracy: 0.9011 - val_loss: 0.3504 - val_binary_accuracy: 0.9024 - lr: 1.0000e-04 - 32s/epoch - 453ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.35043 to 0.29803, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.2792 - binary_accuracy: 0.9136 - val_loss: 0.2980 - val_binary_accuracy: 0.9102 - lr: 1.0000e-04 - 32s/epoch - 452ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 0.29803 to 0.25600, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.2512 - binary_accuracy: 0.9194 - val_loss: 0.2560 - val_binary_accuracy: 0.9107 - lr: 1.0000e-04 - 32s/epoch - 451ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.25600 to 0.24482, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.2402 - binary_accuracy: 0.9187 - val_loss: 0.2448 - val_binary_accuracy: 0.9141 - lr: 1.0000e-04 - 32s/epoch - 452ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.24482 to 0.20811, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.2258 - binary_accuracy: 0.9231 - val_loss: 0.2081 - val_binary_accuracy: 0.9246 - lr: 1.0000e-04 - 32s/epoch - 453ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.20811 to 0.19206, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.2131 - binary_accuracy: 0.9265 - val_loss: 0.1921 - val_binary_accuracy: 0.9297 - lr: 1.0000e-04 - 32s/epoch - 456ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 0.19206 to 0.17258, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.2077 - binary_accuracy: 0.9269 - val_loss: 0.1726 - val_binary_accuracy: 0.9347 - lr: 1.0000e-04 - 32s/epoch - 455ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.17258
# 70/70 - 31s - loss: 0.1927 - binary_accuracy: 0.9329 - val_loss: 0.1887 - val_binary_accuracy: 0.9297 - lr: 1.0000e-04 - 31s/epoch - 441ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.17258
# 70/70 - 31s - loss: 0.1857 - binary_accuracy: 0.9345 - val_loss: 0.1741 - val_binary_accuracy: 0.9333 - lr: 1.0000e-04 - 31s/epoch - 442ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss improved from 0.17258 to 0.15245, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1792 - binary_accuracy: 0.9368 - val_loss: 0.1524 - val_binary_accuracy: 0.9419 - lr: 1.0000e-04 - 32s/epoch - 456ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss improved from 0.15245 to 0.15060, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1763 - binary_accuracy: 0.9375 - val_loss: 0.1506 - val_binary_accuracy: 0.9423 - lr: 1.0000e-04 - 32s/epoch - 455ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.15060
# 70/70 - 31s - loss: 0.1798 - binary_accuracy: 0.9352 - val_loss: 0.1661 - val_binary_accuracy: 0.9373 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.15060
# 70/70 - 31s - loss: 0.1676 - binary_accuracy: 0.9402 - val_loss: 0.1652 - val_binary_accuracy: 0.9424 - lr: 1.0000e-04 - 31s/epoch - 441ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.15060
# 70/70 - 31s - loss: 0.1622 - binary_accuracy: 0.9422 - val_loss: 0.1608 - val_binary_accuracy: 0.9398 - lr: 1.0000e-04 - 31s/epoch - 441ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.15060
# 70/70 - 31s - loss: 0.1601 - binary_accuracy: 0.9423 - val_loss: 0.1554 - val_binary_accuracy: 0.9415 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss improved from 0.15060 to 0.13862, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1572 - binary_accuracy: 0.9438 - val_loss: 0.1386 - val_binary_accuracy: 0.9475 - lr: 1.0000e-04 - 32s/epoch - 454ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.13862
# 70/70 - 31s - loss: 0.1547 - binary_accuracy: 0.9453 - val_loss: 0.1442 - val_binary_accuracy: 0.9445 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.13862
# 70/70 - 31s - loss: 0.1521 - binary_accuracy: 0.9456 - val_loss: 0.1464 - val_binary_accuracy: 0.9444 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.13862
# 70/70 - 31s - loss: 0.1464 - binary_accuracy: 0.9482 - val_loss: 0.1462 - val_binary_accuracy: 0.9448 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.13862
# 70/70 - 31s - loss: 0.1457 - binary_accuracy: 0.9481 - val_loss: 0.1492 - val_binary_accuracy: 0.9439 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.13862
# 70/70 - 31s - loss: 0.1509 - binary_accuracy: 0.9459 - val_loss: 0.1529 - val_binary_accuracy: 0.9441 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.13862
# 70/70 - 31s - loss: 0.1432 - binary_accuracy: 0.9484 - val_loss: 0.1573 - val_binary_accuracy: 0.9419 - lr: 1.0000e-04 - 31s/epoch - 441ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss improved from 0.13862 to 0.13850, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1430 - binary_accuracy: 0.9482 - val_loss: 0.1385 - val_binary_accuracy: 0.9478 - lr: 1.0000e-04 - 32s/epoch - 456ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.13850
# 70/70 - 31s - loss: 0.1432 - binary_accuracy: 0.9485 - val_loss: 0.1402 - val_binary_accuracy: 0.9449 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.13850
# 70/70 - 31s - loss: 0.1413 - binary_accuracy: 0.9492 - val_loss: 0.1815 - val_binary_accuracy: 0.9326 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.13850
# 70/70 - 31s - loss: 0.1443 - binary_accuracy: 0.9485 - val_loss: 0.1514 - val_binary_accuracy: 0.9445 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss improved from 0.13850 to 0.13723, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1427 - binary_accuracy: 0.9482 - val_loss: 0.1372 - val_binary_accuracy: 0.9498 - lr: 1.0000e-04 - 32s/epoch - 454ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.13723
# 70/70 - 31s - loss: 0.1382 - binary_accuracy: 0.9507 - val_loss: 0.1647 - val_binary_accuracy: 0.9388 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 0.13723
# 70/70 - 31s - loss: 0.1384 - binary_accuracy: 0.9499 - val_loss: 0.1383 - val_binary_accuracy: 0.9469 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 0.13723
# 70/70 - 31s - loss: 0.1343 - binary_accuracy: 0.9518 - val_loss: 0.1485 - val_binary_accuracy: 0.9460 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.13723
# 70/70 - 31s - loss: 0.1279 - binary_accuracy: 0.9541 - val_loss: 0.1430 - val_binary_accuracy: 0.9466 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss improved from 0.13723 to 0.13307, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1224 - binary_accuracy: 0.9562 - val_loss: 0.1331 - val_binary_accuracy: 0.9499 - lr: 1.0000e-04 - 32s/epoch - 453ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss improved from 0.13307 to 0.13204, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1255 - binary_accuracy: 0.9551 - val_loss: 0.1320 - val_binary_accuracy: 0.9496 - lr: 1.0000e-04 - 32s/epoch - 454ms/step
# Epoch 35/1000
# Epoch 35: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1280 - binary_accuracy: 0.9538 - val_loss: 0.1421 - val_binary_accuracy: 0.9455 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1218 - binary_accuracy: 0.9565 - val_loss: 0.1392 - val_binary_accuracy: 0.9461 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1288 - binary_accuracy: 0.9541 - val_loss: 0.1393 - val_binary_accuracy: 0.9484 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1240 - binary_accuracy: 0.9556 - val_loss: 0.1432 - val_binary_accuracy: 0.9437 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1214 - binary_accuracy: 0.9563 - val_loss: 0.1577 - val_binary_accuracy: 0.9425 - lr: 1.0000e-04 - 31s/epoch - 438ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1308 - binary_accuracy: 0.9534 - val_loss: 0.1507 - val_binary_accuracy: 0.9445 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1238 - binary_accuracy: 0.9554 - val_loss: 0.1903 - val_binary_accuracy: 0.9318 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1238 - binary_accuracy: 0.9559 - val_loss: 0.1427 - val_binary_accuracy: 0.9453 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 0.13204
# 70/70 - 31s - loss: 0.1221 - binary_accuracy: 0.9557 - val_loss: 0.1647 - val_binary_accuracy: 0.9379 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss improved from 0.13204 to 0.13106, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1230 - binary_accuracy: 0.9559 - val_loss: 0.1311 - val_binary_accuracy: 0.9506 - lr: 1.0000e-04 - 32s/epoch - 454ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss improved from 0.13106 to 0.12746, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1222 - binary_accuracy: 0.9569 - val_loss: 0.1275 - val_binary_accuracy: 0.9511 - lr: 1.0000e-04 - 32s/epoch - 452ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 0.12746
# 70/70 - 31s - loss: 0.1197 - binary_accuracy: 0.9569 - val_loss: 0.1310 - val_binary_accuracy: 0.9499 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 0.12746
# 70/70 - 31s - loss: 0.1191 - binary_accuracy: 0.9572 - val_loss: 0.3240 - val_binary_accuracy: 0.9063 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss improved from 0.12746 to 0.12100, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1159 - binary_accuracy: 0.9581 - val_loss: 0.1210 - val_binary_accuracy: 0.9538 - lr: 1.0000e-04 - 32s/epoch - 455ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 0.12100
# 70/70 - 31s - loss: 0.1164 - binary_accuracy: 0.9581 - val_loss: 0.1612 - val_binary_accuracy: 0.9383 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 0.12100
# 70/70 - 31s - loss: 0.1196 - binary_accuracy: 0.9569 - val_loss: 0.1469 - val_binary_accuracy: 0.9443 - lr: 1.0000e-04 - 31s/epoch - 441ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss improved from 0.12100 to 0.11868, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1183 - binary_accuracy: 0.9578 - val_loss: 0.1187 - val_binary_accuracy: 0.9553 - lr: 1.0000e-04 - 32s/epoch - 453ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1190 - binary_accuracy: 0.9575 - val_loss: 0.1327 - val_binary_accuracy: 0.9478 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1111 - binary_accuracy: 0.9602 - val_loss: 0.1275 - val_binary_accuracy: 0.9515 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1146 - binary_accuracy: 0.9582 - val_loss: 0.1300 - val_binary_accuracy: 0.9499 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1131 - binary_accuracy: 0.9595 - val_loss: 0.1243 - val_binary_accuracy: 0.9529 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1072 - binary_accuracy: 0.9612 - val_loss: 0.1267 - val_binary_accuracy: 0.9516 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1093 - binary_accuracy: 0.9604 - val_loss: 0.1255 - val_binary_accuracy: 0.9529 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1108 - binary_accuracy: 0.9601 - val_loss: 0.1420 - val_binary_accuracy: 0.9459 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1113 - binary_accuracy: 0.9600 - val_loss: 0.1270 - val_binary_accuracy: 0.9505 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1107 - binary_accuracy: 0.9602 - val_loss: 0.1284 - val_binary_accuracy: 0.9524 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1165 - binary_accuracy: 0.9581 - val_loss: 0.1202 - val_binary_accuracy: 0.9548 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1115 - binary_accuracy: 0.9600 - val_loss: 0.1260 - val_binary_accuracy: 0.9522 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1128 - binary_accuracy: 0.9591 - val_loss: 0.1476 - val_binary_accuracy: 0.9434 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 0.11868
# 70/70 - 31s - loss: 0.1098 - binary_accuracy: 0.9600 - val_loss: 0.1223 - val_binary_accuracy: 0.9526 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss improved from 0.11868 to 0.11316, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp3.h5
# 70/70 - 32s - loss: 0.1058 - binary_accuracy: 0.9616 - val_loss: 0.1132 - val_binary_accuracy: 0.9568 - lr: 1.0000e-04 - 32s/epoch - 455ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1046 - binary_accuracy: 0.9626 - val_loss: 0.1249 - val_binary_accuracy: 0.9534 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1110 - binary_accuracy: 0.9602 - val_loss: 0.1190 - val_binary_accuracy: 0.9545 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1046 - binary_accuracy: 0.9619 - val_loss: 0.1414 - val_binary_accuracy: 0.9487 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1067 - binary_accuracy: 0.9614 - val_loss: 0.1534 - val_binary_accuracy: 0.9418 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1031 - binary_accuracy: 0.9626 - val_loss: 0.1489 - val_binary_accuracy: 0.9421 - lr: 1.0000e-04 - 31s/epoch - 438ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1100 - binary_accuracy: 0.9600 - val_loss: 0.1637 - val_binary_accuracy: 0.9400 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1025 - binary_accuracy: 0.9625 - val_loss: 0.1194 - val_binary_accuracy: 0.9555 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1072 - binary_accuracy: 0.9613 - val_loss: 0.2184 - val_binary_accuracy: 0.9230 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1054 - binary_accuracy: 0.9618 - val_loss: 0.1399 - val_binary_accuracy: 0.9457 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1001 - binary_accuracy: 0.9636 - val_loss: 0.1224 - val_binary_accuracy: 0.9546 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1026 - binary_accuracy: 0.9627 - val_loss: 0.1321 - val_binary_accuracy: 0.9499 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1102 - binary_accuracy: 0.9600 - val_loss: 0.1991 - val_binary_accuracy: 0.9302 - lr: 1.0000e-04 - 31s/epoch - 439ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1011 - binary_accuracy: 0.9633 - val_loss: 0.1338 - val_binary_accuracy: 0.9480 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.1000 - binary_accuracy: 0.9633 - val_loss: 0.1195 - val_binary_accuracy: 0.9531 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 0.11316
# 70/70 - 31s - loss: 0.0994 - binary_accuracy: 0.9636 - val_loss: 0.1234 - val_binary_accuracy: 0.9529 - lr: 1.0000e-04 - 31s/epoch - 440ms/step
# Epoch 80: early stopping
# Done

# %%
'''
SCORE
'''
print("Experiment 3a")
DeepLab_Score(
    exp3_model, exp3_weights_filename, exp3_metrics_filename, exp3_comb_X_test_a, exp3_y_test_a)

print("\nExperiment 3b")
DeepLab_Score(
    exp3_model, exp3_weights_filename, exp3_metrics_filename, exp3_comb_X_test_b, exp3_y_test_b)

print("Done")
# Out:
# Experiment 3a
# 216/216 [==============================] - 20s 87ms/step - loss: 0.4182 - binary_accuracy: 0.8766
# Test loss: 0.41818752884864807
# Test accuracy: 0.8766326904296875
#
# Experiment 3b
# 70/70 [==============================] - 6s 82ms/step - loss: 0.1155 - binary_accuracy: 0.9557
# Test loss: 0.115524522960186
# Test accuracy: 0.9557182192802429
# Done

# %%
'''
PREDICT
'''
print("Experiment 3a")
exp3_y_pred_a = DeepLab_Predict(exp3_model, exp3_comb_X_test_a)

print("\nExperiment 3b")
exp3_y_pred_b = DeepLab_Predict(exp3_model, exp3_comb_X_test_b)

print("Done")
# Out:
# Experiment 3a
# 108/108 [==============================] - 17s 148ms/step
# 2023-10-19 02:29:02.904125: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3948456512 exceeds 10% of free system memory.
# Experiment 3b
# 35/35 [==============================] - 5s 149ms/step
# Done

# %%
'''
DISPLAY RANDOM RESULT
'''
print("Experiment 3a")
DeepLab_Display(exp3_comb_X_test_a, exp3_y_test_a, exp3_y_pred_a)

print("\nExperiment 3b")
DeepLab_Display(exp3_comb_X_test_b, exp3_y_test_b, exp3_y_pred_b)
# Out:
# Experiment 3a
# Experiment 3b

# %%
'''
METRICS
'''
print("Experiment 3a")
DeepLab_Metrics(exp3_y_test_a, exp3_y_pred_a, exp3_metrics_filename)

print("\nExperiment 3b")
DeepLab_Metrics(exp3_y_test_b, exp3_y_pred_b, exp3_metrics_filename)
# Out:
# Experiment 3a
# Mean IoU: 0.27691105918220604
# Pixel accuracy: 0.5519511701285265
# Mean accuracy: 0.4306614265204978
# Frequency-Weighted IoU: 0.5476394552994487
#
# Experiment 3b
# Mean IoU: 0.615600436077089
# Pixel accuracy: 0.8413124681262794
# Mean accuracy: 0.7473183366805606
# Frequency-Weighted IoU: 0.8157823468912125
