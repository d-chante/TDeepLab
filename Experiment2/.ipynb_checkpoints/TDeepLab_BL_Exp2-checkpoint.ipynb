# %% [markdown]
# # DeepLab

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dropout, Activation, UpSampling2D
from tensorflow.keras.layers import AveragePooling2D, Conv2DTranspose, Concatenate, Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.image import resize, ResizeMethod
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from PIL import Image

import random
import os
import numpy as np
from numpy import load
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:0'

get_ipython().system('nvidia-smi')

'''
TRAINING DATA
'''
exp2_rgb_X_train = load(TRAIN_DIR + '/exp2_rgb_X_train_dl.npy')
exp2_ir_X_train = load(TRAIN_DIR + '/exp2_ir_X_train_dl.npy')
exp2_y_train = load(TRAIN_DIR + '/exp2_y_train_dl.npy')

'''
VALIDATION DATA
'''
exp2_rgb_X_val = load(VAL_DIR + '/exp2_rgb_X_val_dl.npy')
exp2_ir_X_val = load(VAL_DIR + '/exp2_ir_X_val_dl.npy')
exp2_y_val = load(VAL_DIR + '/exp2_y_val_dl.npy')

'''
TEST DATA
'''
exp2_rgb_X_test = load(TEST_DIR + '/exp2_rgb_X_test_dl.npy')
exp2_ir_X_test = load(TEST_DIR + '/exp2_ir_X_test_dl.npy')
exp2_y_test = load(TEST_DIR + '/exp2_y_test_dl.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FREQUENCY-WEIGHTED INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', 7)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(7), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# 2023-10-15 19:59:59.907452: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sun Oct 15 20:00:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   31C    P8     9W / 250W |      0MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Done

# %%
'''
COMBINE RGB/IR IMAGES
'''
def combine_rgb_ir(rgb_images, ir_images):
    combined_images = []
    
    for i in range(len(ir_images)):
        ir = np.dstack([ir_images[i]] * 3)
        rgb = np.asarray(rgb_images[i], dtype=np.uint8)

        comb = ir + rgb
        comb = Image.fromarray(comb)
        comb = comb.resize((572, 572))
        comb = np.asarray(comb)

        combined_images.append(comb)
    
    return np.array(combined_images)

exp2_comb_X_train = combine_rgb_ir(exp2_rgb_X_train, exp2_ir_X_train)
exp2_comb_X_val = combine_rgb_ir(exp2_rgb_X_val, exp2_ir_X_val)
exp2_comb_X_test = combine_rgb_ir(exp2_rgb_X_test, exp2_ir_X_test)

# %%
'''
MODEL PARAMS
'''
INPUT_DIMS = (572, 572, 3)

BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

DROPOUT_RATE = 0.5

TRAINABLE_LAYERS = 300

LOSS_ = BinaryCrossentropy()
METRICS_ = [BinaryAccuracy()]

EXP2_FILENAME = "tdeeplab_bl_exp2_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done
# 2023-10-15 20:00:06.286961: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:06.292028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:06.292266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:06.293585: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:06.293795: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:06.293987: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:07.038843: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:07.039138: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:07.039390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 20:00:07.039593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 23635 MB memory:  -> device: 0, name: Tesla P40, pci bus id: 0000:05:00.0, compute capability: 6.1

# %% [markdown]
# ### DeepLab Common

# %%
'''
Atrous Spatial Pyramid Pooling
'''
def ASPP(inputs):
    shape = inputs.shape

    y_pool = AveragePooling2D(pool_size=(shape[1], shape[2]), name='average_pooling')(inputs)
    y_pool = Conv2D(filters=256, kernel_size=1, padding='same', use_bias=False)(y_pool)
    y_pool = BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = Activation('relu', name=f'relu_1')(y_pool)
    y_pool = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y_pool)

    y_1 = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(inputs)
    y_1 = BatchNormalization()(y_1)
    y_1 = Activation('relu')(y_1)

    y_6 = Conv2D(filters=256, kernel_size=3, dilation_rate=6, padding='same', use_bias=False)(inputs)
    y_6 = BatchNormalization()(y_6)
    y_6 = Activation('relu')(y_6)

    y_12 = Conv2D(filters=256, kernel_size=3, dilation_rate=12, padding='same', use_bias=False)(inputs)
    y_12 = BatchNormalization()(y_12)
    y_12 = Activation('relu')(y_12)

    y_18 = Conv2D(filters=256, kernel_size=3, dilation_rate=18, padding='same', use_bias=False)(inputs)
    y_18 = BatchNormalization()(y_18)
    y_18 = Activation('relu')(y_18)

    y = Concatenate()([y_pool, y_1, y_6, y_12, y_18])

    y = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    return y

def DeepLab(shape):
    """ Inputs """
    inputs = Input(shape)
    
    """ Pre-trained ResNet101 """
    base_model = ResNet101(weights='imagenet', include_top=False, input_tensor=inputs)
    
    for layer in base_model.layers[:TRAINABLE_LAYERS]:
        layer.trainable = False
    for layer in base_model.layers[TRAINABLE_LAYERS:]:
        layer.trainable = True

    """ Pre-trained ResNet101 Output """
    image_features = base_model.get_layer('conv4_block23_out').output
    x_a = ASPP(image_features)
    x_a = UpSampling2D((4, 4), interpolation="bilinear")(x_a)

    """ Get low-level features """
    x_b = base_model.get_layer('conv2_block2_out').output
    x_b = Conv2D(filters=48, kernel_size=1, padding='same', use_bias=False)(x_b)
    x_b = BatchNormalization()(x_b)
    x_b = Activation('relu')(x_b)

    """ Spatial Pyramid Pooling (SPP) """
    # Apply different pooling sizes
    pool1 = GlobalAveragePooling2D()(x_a)
    pool2 = GlobalAveragePooling2D()(x_a)
    pool3 = GlobalAveragePooling2D()(x_a)

    # Concatenate pooled features
    spp_features = Concatenate()([pool1, pool2, pool3])

    # Reshape to match x_b's shape
    spp_features = tf.keras.layers.Reshape((1, 1, -1))(spp_features)
    spp_features = UpSampling2D((x_b.shape[1], x_b.shape[2]), interpolation="bilinear")(spp_features)

    x = Concatenate()([spp_features, x_b])

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)
    x = UpSampling2D((4, 4), interpolation="bilinear")(x)

    """ Outputs """
    x = Conv2D(7, (1, 1), name='output_layer')(x)
    x = Activation('softmax')(x)

    """ Model """
    model = Model(inputs=inputs, outputs=x)
    return model

'''
TRAIN
'''
def DeepLab_Train(model, X_train, y_train, X_val, y_val, weights_filename):
    
    try:
        with tf.device(gpu_p40):
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss=LOSS_, 
                metrics=METRICS_)
            
            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
            
            history = model.fit(
                X_train, y_train,
                validation_data=(X_val, y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
            
    except RuntimeError as e:
        print(e)

'''
SCORE
'''
def DeepLab_Score(model, weights_filename, metrics_filename, X_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            score = model.evaluate(X_test, y_test, batch_size=2, verbose=1)

    except RuntimeError as e:
        print(e)

    # Print and save the test metrics
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])

    with open(metrics_filename, "a") as f:
        f.write(f"\Test Loss: {score[0]}\n")
        f.write(f"\Test Accuracy: {score[1]}\n")
        
'''
PREDICT
'''
def DeepLab_Predict(model, X_rgb_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test], batch_size=BATCH_SIZE)
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def DeepLab_Display(X_rgb_test, y_test, y_pred):

    try:
        with tf.device(gpu_p40):
            fig, axes = plt.subplots(1, 3, figsize=(10, 6))
            n = random.randint(0, len(X_rgb_test)-1)
            cmap = plt.get_cmap('tab10', 7)
    
            axes[0].imshow(X_rgb_test[n])
            axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
            axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
            axes[0].set_title("RGB")
            axes[1].set_title("Annotation")
            axes[2].set_title("Predicted")
    
            for ax in axes.flatten():
                ax.axis("off")
        
            plt.tight_layout()
            plt.show()
            
    except RuntimeError as e:
        print(e)
'''
METRICS
'''
def DeepLab_Metrics(y_test, y_pred, metrics_filename):

    try:
        with tf.device(gpu_p40):
            y_pred_classes = np.argmax(y_pred, axis=-1)
            y_true_classes = np.argmax(y_test, axis=-1)
    
            num_classes=7

            iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
            pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
            mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
            fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)

            print(f"Mean IoU: {mean_iou}")
            print(f"Pixel accuracy: {pixel_acc}")
            print(f"Mean accuracy: {mean_acc}")
            print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
            with open(metrics_filename, "a") as f:
                f.write("\nIoU Values:\n")
                for i, iou_val in enumerate(iou_values):
                    f.write(f"Class {i}: {iou_val}\n")
                f.write(f"\nMean IoU: {mean_iou}\n")
                f.write(f"Pixel Accuracy: {pixel_acc}\n")
                f.write(f"Mean Accuracy: {mean_acc}\n")
                f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    except RuntimeError as e:
        print(e)

print("Done")
# Out:
# Done

# %%
'''
FILENAMES
'''
exp2_weights_filename = os.path.join(WEIGHTS_PATH, 'tdeeplab_bl_exp2.h5')
exp2_metrics_filename = os.path.join(METRICS_PATH, 'tdeeplab_bl_exp2.txt')

print("Done")
# Out:
# Done

# %%
'''
model
'''
try:
    with tf.device(gpu_p40):
        exp2_model = DeepLab(INPUT_DIMS)         
except RuntimeError as e:
    print(e)

print("Done")
# Out:
# Done

# %%
'''
TRAIN
'''
DeepLab_Train(
    exp2_model, exp2_comb_X_train, exp2_y_train, exp2_comb_X_val, exp2_y_val, exp2_weights_filename)

print("Done")
# Out:
# Epoch 1/1000
# 2023-10-15 20:00:17.543828: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-15 20:00:18.871532: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-10-15 20:00:20.886099: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f03917a0a10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-15 20:00:20.886139: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla P40, Compute Capability 6.1
# 2023-10-15 20:00:20.891592: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-15 20:00:21.044570: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 0.36489, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 74s - loss: 0.4017 - binary_accuracy: 0.8718 - val_loss: 0.3649 - val_binary_accuracy: 0.8912 - lr: 1.0000e-04 - 74s/epoch - 301ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.36489
# 247/247 - 55s - loss: 0.2999 - binary_accuracy: 0.8859 - val_loss: 0.4220 - val_binary_accuracy: 0.8957 - lr: 1.0000e-04 - 55s/epoch - 223ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.36489
# 247/247 - 55s - loss: 0.2763 - binary_accuracy: 0.8916 - val_loss: 0.4156 - val_binary_accuracy: 0.8978 - lr: 1.0000e-04 - 55s/epoch - 224ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 0.36489 to 0.34999, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.2629 - binary_accuracy: 0.8957 - val_loss: 0.3500 - val_binary_accuracy: 0.9023 - lr: 1.0000e-04 - 57s/epoch - 229ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.34999
# 247/247 - 56s - loss: 0.2485 - binary_accuracy: 0.9015 - val_loss: 0.3708 - val_binary_accuracy: 0.9077 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.34999 to 0.33013, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 56s - loss: 0.2446 - binary_accuracy: 0.9031 - val_loss: 0.3301 - val_binary_accuracy: 0.9111 - lr: 1.0000e-04 - 56s/epoch - 228ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.33013 to 0.28225, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.2367 - binary_accuracy: 0.9063 - val_loss: 0.2822 - val_binary_accuracy: 0.9121 - lr: 1.0000e-04 - 57s/epoch - 230ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 0.28225 to 0.27936, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 56s - loss: 0.2331 - binary_accuracy: 0.9093 - val_loss: 0.2794 - val_binary_accuracy: 0.9145 - lr: 1.0000e-04 - 56s/epoch - 229ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 0.27936 to 0.26626, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.2317 - binary_accuracy: 0.9093 - val_loss: 0.2663 - val_binary_accuracy: 0.9132 - lr: 1.0000e-04 - 57s/epoch - 229ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.26626
# 247/247 - 56s - loss: 0.2277 - binary_accuracy: 0.9115 - val_loss: 0.2732 - val_binary_accuracy: 0.9144 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss improved from 0.26626 to 0.25791, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.2223 - binary_accuracy: 0.9148 - val_loss: 0.2579 - val_binary_accuracy: 0.9200 - lr: 1.0000e-04 - 57s/epoch - 230ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.25791
# 247/247 - 56s - loss: 0.2144 - binary_accuracy: 0.9182 - val_loss: 0.2926 - val_binary_accuracy: 0.9188 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.25791
# 247/247 - 56s - loss: 0.2082 - binary_accuracy: 0.9206 - val_loss: 0.2873 - val_binary_accuracy: 0.9150 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss improved from 0.25791 to 0.25658, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.2051 - binary_accuracy: 0.9217 - val_loss: 0.2566 - val_binary_accuracy: 0.9231 - lr: 1.0000e-04 - 57s/epoch - 230ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.2053 - binary_accuracy: 0.9227 - val_loss: 0.2678 - val_binary_accuracy: 0.9187 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.2032 - binary_accuracy: 0.9232 - val_loss: 0.2571 - val_binary_accuracy: 0.9143 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.2024 - binary_accuracy: 0.9236 - val_loss: 0.2901 - val_binary_accuracy: 0.9174 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1918 - binary_accuracy: 0.9282 - val_loss: 0.2780 - val_binary_accuracy: 0.9148 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1986 - binary_accuracy: 0.9260 - val_loss: 0.3066 - val_binary_accuracy: 0.9138 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1953 - binary_accuracy: 0.9268 - val_loss: 0.3261 - val_binary_accuracy: 0.9160 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1911 - binary_accuracy: 0.9287 - val_loss: 0.2696 - val_binary_accuracy: 0.9224 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1911 - binary_accuracy: 0.9291 - val_loss: 0.2967 - val_binary_accuracy: 0.9203 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1808 - binary_accuracy: 0.9343 - val_loss: 0.2709 - val_binary_accuracy: 0.9224 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1801 - binary_accuracy: 0.9337 - val_loss: 0.2676 - val_binary_accuracy: 0.9183 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1855 - binary_accuracy: 0.9321 - val_loss: 0.3375 - val_binary_accuracy: 0.9202 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1762 - binary_accuracy: 0.9351 - val_loss: 0.2720 - val_binary_accuracy: 0.9221 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.25658
# 247/247 - 56s - loss: 0.1803 - binary_accuracy: 0.9334 - val_loss: 0.2588 - val_binary_accuracy: 0.9203 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss improved from 0.25658 to 0.24429, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.1774 - binary_accuracy: 0.9354 - val_loss: 0.2443 - val_binary_accuracy: 0.9267 - lr: 1.0000e-04 - 57s/epoch - 231ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.24429
# 247/247 - 56s - loss: 0.1764 - binary_accuracy: 0.9359 - val_loss: 0.2663 - val_binary_accuracy: 0.9189 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss improved from 0.24429 to 0.24014, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.1708 - binary_accuracy: 0.9382 - val_loss: 0.2401 - val_binary_accuracy: 0.9260 - lr: 1.0000e-04 - 57s/epoch - 229ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1717 - binary_accuracy: 0.9375 - val_loss: 0.2862 - val_binary_accuracy: 0.9287 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1717 - binary_accuracy: 0.9376 - val_loss: 0.2443 - val_binary_accuracy: 0.9267 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1659 - binary_accuracy: 0.9397 - val_loss: 0.2562 - val_binary_accuracy: 0.9276 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1643 - binary_accuracy: 0.9406 - val_loss: 0.2774 - val_binary_accuracy: 0.9216 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1643 - binary_accuracy: 0.9398 - val_loss: 0.2472 - val_binary_accuracy: 0.9293 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1640 - binary_accuracy: 0.9404 - val_loss: 0.2723 - val_binary_accuracy: 0.9271 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1587 - binary_accuracy: 0.9427 - val_loss: 0.2679 - val_binary_accuracy: 0.9238 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1613 - binary_accuracy: 0.9414 - val_loss: 0.2489 - val_binary_accuracy: 0.9303 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 0.24014
# 247/247 - 56s - loss: 0.1566 - binary_accuracy: 0.9436 - val_loss: 0.2450 - val_binary_accuracy: 0.9236 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss improved from 0.24014 to 0.23287, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.1532 - binary_accuracy: 0.9443 - val_loss: 0.2329 - val_binary_accuracy: 0.9289 - lr: 1.0000e-04 - 57s/epoch - 229ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1635 - binary_accuracy: 0.9406 - val_loss: 0.2904 - val_binary_accuracy: 0.9193 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1578 - binary_accuracy: 0.9421 - val_loss: 0.2441 - val_binary_accuracy: 0.9289 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1539 - binary_accuracy: 0.9442 - val_loss: 0.2735 - val_binary_accuracy: 0.9273 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1585 - binary_accuracy: 0.9419 - val_loss: 0.2657 - val_binary_accuracy: 0.9264 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1502 - binary_accuracy: 0.9451 - val_loss: 0.2655 - val_binary_accuracy: 0.9285 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1540 - binary_accuracy: 0.9442 - val_loss: 0.2462 - val_binary_accuracy: 0.9316 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1525 - binary_accuracy: 0.9443 - val_loss: 0.2751 - val_binary_accuracy: 0.9293 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1553 - binary_accuracy: 0.9434 - val_loss: 0.2442 - val_binary_accuracy: 0.9304 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1452 - binary_accuracy: 0.9472 - val_loss: 0.2555 - val_binary_accuracy: 0.9305 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 0.23287
# 247/247 - 56s - loss: 0.1509 - binary_accuracy: 0.9446 - val_loss: 0.2410 - val_binary_accuracy: 0.9336 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss improved from 0.23287 to 0.21332, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp2.h5
# 247/247 - 57s - loss: 0.1485 - binary_accuracy: 0.9461 - val_loss: 0.2133 - val_binary_accuracy: 0.9303 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1473 - binary_accuracy: 0.9462 - val_loss: 0.2447 - val_binary_accuracy: 0.9322 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1539 - binary_accuracy: 0.9433 - val_loss: 0.2497 - val_binary_accuracy: 0.9280 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1499 - binary_accuracy: 0.9451 - val_loss: 0.2674 - val_binary_accuracy: 0.9265 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1444 - binary_accuracy: 0.9476 - val_loss: 0.2568 - val_binary_accuracy: 0.9299 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1459 - binary_accuracy: 0.9469 - val_loss: 0.2254 - val_binary_accuracy: 0.9338 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1500 - binary_accuracy: 0.9452 - val_loss: 0.2369 - val_binary_accuracy: 0.9342 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1426 - binary_accuracy: 0.9482 - val_loss: 0.2149 - val_binary_accuracy: 0.9362 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1446 - binary_accuracy: 0.9475 - val_loss: 0.3023 - val_binary_accuracy: 0.9183 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1448 - binary_accuracy: 0.9469 - val_loss: 0.2377 - val_binary_accuracy: 0.9334 - lr: 1.0000e-04 - 56s/epoch - 225ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1443 - binary_accuracy: 0.9472 - val_loss: 0.2205 - val_binary_accuracy: 0.9347 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1418 - binary_accuracy: 0.9487 - val_loss: 0.2292 - val_binary_accuracy: 0.9343 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1412 - binary_accuracy: 0.9485 - val_loss: 0.2419 - val_binary_accuracy: 0.9352 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1441 - binary_accuracy: 0.9474 - val_loss: 0.2185 - val_binary_accuracy: 0.9363 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1382 - binary_accuracy: 0.9501 - val_loss: 0.2138 - val_binary_accuracy: 0.9347 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 0.21332
# 247/247 - 56s - loss: 0.1399 - binary_accuracy: 0.9492 - val_loss: 0.2304 - val_binary_accuracy: 0.9320 - lr: 1.0000e-04 - 56s/epoch - 226ms/step
# Epoch 66: early stopping
# Done

# %%
'''
SCORE
'''
DeepLab_Score(
    exp2_model, exp2_weights_filename, exp2_metrics_filename, exp2_comb_X_test, exp2_y_test)

print("Done")
# Out:
# 124/124 [==============================] - 10s 83ms/step - loss: 0.2344 - binary_accuracy: 0.9329
# Test loss: 0.23438119888305664
# Test accuracy: 0.9328716397285461
# Done

# %%
'''
PREDICT
'''
exp2_y_pred = DeepLab_Predict(exp2_model, exp2_comb_X_test)

print("Done")
# Out:
# 124/124 [==============================] - 11s 75ms/step
# Done

# %%
'''
DISPLAY RANDOM RESULT
'''
DeepLab_Display(exp2_comb_X_test, exp2_y_test, exp2_y_pred)

# %%
'''
METRICS
'''
DeepLab_Metrics(exp2_y_test, exp2_y_pred, exp2_metrics_filename)
# Out:
# Mean IoU: 0.49754330152204573
# Pixel accuracy: 0.7608523328690259
# Mean accuracy: 0.6438637478395223
# Frequency-Weighted IoU: 0.7424453562552988
