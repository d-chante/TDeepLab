# %% [markdown]
# # DeepLab

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.keras.layers import Average, Conv2D, BatchNormalization, Dropout, Activation, UpSampling2D
from tensorflow.keras.layers import AveragePooling2D, Conv2DTranspose, Concatenate, Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.image import resize, ResizeMethod
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from PIL import Image

import random
import os
import numpy as np
from numpy import load
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:0'

get_ipython().system('nvidia-smi')

'''
TRAINING DATA
'''
exp2_rgb_X_train = load(TRAIN_DIR + '/exp2_rgb_X_train_dl.npy')
exp2_ir_X_train = load(TRAIN_DIR + '/exp2_ir_X_train_dl.npy')
exp2_y_train = load(TRAIN_DIR + '/exp2_y_train_dl.npy')

'''
VALIDATION DATA
'''
exp2_rgb_X_val = load(VAL_DIR + '/exp2_rgb_X_val_dl.npy')
exp2_ir_X_val = load(VAL_DIR + '/exp2_ir_X_val_dl.npy')
exp2_y_val = load(VAL_DIR + '/exp2_y_val_dl.npy')

'''
TEST DATA
'''
exp2_rgb_X_test = load(TEST_DIR + '/exp2_rgb_X_test_dl.npy')
exp2_ir_X_test = load(TEST_DIR + '/exp2_ir_X_test_dl.npy')
exp2_y_test = load(TEST_DIR + '/exp2_y_test_dl.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FREQUENCY-WEIGHTED INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', 7)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(7), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# Tue Oct 17 23:53:27 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   34C    P0    49W / 250W |  23946MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# Done

# %%
'''
COMBINE RGB/IR IMAGES
'''
def combine_rgb_ir(rgb_images, ir_images):
    combined_images = []
    
    for i in range(len(ir_images)):
        ir = np.dstack([ir_images[i]] * 3)
        rgb = np.asarray(rgb_images[i], dtype=np.uint8)

        comb = ir + rgb
        comb = Image.fromarray(comb)
        comb = comb.resize((572, 572))
        comb = np.asarray(comb)

        combined_images.append(comb)
    
    return np.array(combined_images)

exp2_comb_X_train = combine_rgb_ir(exp2_rgb_X_train, exp2_ir_X_train)
exp2_comb_X_val = combine_rgb_ir(exp2_rgb_X_val, exp2_ir_X_val)
exp2_comb_X_test = combine_rgb_ir(exp2_rgb_X_test, exp2_ir_X_test)

# %%
'''
MODEL PARAMS
'''
INPUT_DIMS = (572, 572, 3)

BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

DROPOUT_RATE = 0.5

TRAINABLE_LAYERS = 300

LOSS_ = BinaryCrossentropy()
METRICS_ = [BinaryAccuracy()]

EXP2_FILENAME = "tdeeplab_siamese_bl_exp2_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done
# 2023-10-17 23:52:34.180800: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:34.339592: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:34.339971: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:34.342003: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:34.343770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:34.344092: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:41.031586: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:41.031971: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:41.032303: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-17 23:52:41.032573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 23635 MB memory:  -> device: 0, name: Tesla P40, pci bus id: 0000:05:00.0, compute capability: 6.1

# %% [markdown]
# ### DeepLab Common

# %%
'''
Atrous Spatial Pyramid Pooling
'''
def ASPP(inputs):
    shape = inputs.shape

    y_pool = AveragePooling2D(pool_size=(shape[1], shape[2]), name='average_pooling')(inputs)
    y_pool = Conv2D(filters=256, kernel_size=1, padding='same', use_bias=False)(y_pool)
    y_pool = BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = Activation('relu', name=f'relu_1')(y_pool)
    y_pool = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y_pool)

    y_1 = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(inputs)
    y_1 = BatchNormalization()(y_1)
    y_1 = Activation('relu')(y_1)

    y_6 = Conv2D(filters=256, kernel_size=3, dilation_rate=6, padding='same', use_bias=False)(inputs)
    y_6 = BatchNormalization()(y_6)
    y_6 = Activation('relu')(y_6)

    y_12 = Conv2D(filters=256, kernel_size=3, dilation_rate=12, padding='same', use_bias=False)(inputs)
    y_12 = BatchNormalization()(y_12)
    y_12 = Activation('relu')(y_12)

    y_18 = Conv2D(filters=256, kernel_size=3, dilation_rate=18, padding='same', use_bias=False)(inputs)
    y_18 = BatchNormalization()(y_18)
    y_18 = Activation('relu')(y_18)

    y = Concatenate()([y_pool, y_1, y_6, y_12, y_18])

    y = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    return y

def DeepLab(shape):
    """ Inputs """
    inputs = Input(shape)
    
    """ Pre-trained ResNet101 """
    base_model = ResNet101(weights='imagenet', include_top=False, input_tensor=inputs)
    
    for layer in base_model.layers[:TRAINABLE_LAYERS]:
        layer.trainable = False
    for layer in base_model.layers[TRAINABLE_LAYERS:]:
        layer.trainable = True

    """ Pre-trained ResNet101 Output """
    image_features = base_model.get_layer('conv4_block23_out').output
    x_a = ASPP(image_features)
    x_a = UpSampling2D((4, 4), interpolation="bilinear")(x_a)

    """ Get low-level features """
    x_b = base_model.get_layer('conv2_block2_out').output
    x_b = Conv2D(filters=48, kernel_size=1, padding='same', use_bias=False)(x_b)
    x_b = BatchNormalization()(x_b)
    x_b = Activation('relu')(x_b)

    """ Spatial Pyramid Pooling (SPP) """
    # Apply different pooling sizes
    pool1 = GlobalAveragePooling2D()(x_a)
    pool2 = GlobalAveragePooling2D()(x_a)
    pool3 = GlobalAveragePooling2D()(x_a)

    # Concatenate pooled features
    spp_features = Concatenate()([pool1, pool2, pool3])

    # Reshape to match x_b's shape
    spp_features = tf.keras.layers.Reshape((1, 1, -1))(spp_features)
    spp_features = UpSampling2D((x_b.shape[1], x_b.shape[2]), interpolation="bilinear")(spp_features)

    x = Concatenate()([spp_features, x_b])

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)
    x = UpSampling2D((4, 4), interpolation="bilinear")(x)

    """ Outputs """
    x = Conv2D(7, (1, 1), name='output_layer')(x)
    x = Activation('softmax')(x)

    """ Model """
    model = Model(inputs=inputs, outputs=x)
    return model

def TDeepLab_SiameseBL():
    '''
    BASE MODELS
    '''
    b1 = DeepLab(INPUT_DIMS)
    b2 = DeepLab(INPUT_DIMS)
    
    b2.set_weights(b1.get_weights())
    
    '''
    INPUTS
    '''
    input1 = Input(INPUT_DIMS)
    input2 = Input(INPUT_DIMS)
    
    '''
    OUTPUTS
    '''
    output1 = b1(input1)
    output2 = b2(input2)
    
    avg_output = Average()([output1, output2])
    
    '''
    MODEL
    '''
    model = Model(inputs=[input1, input2], outputs=avg_output)
    
    '''
    RETURN
    '''
    return model

'''
TRAIN
'''
def DeepLab_Train(model, X_train, y_train, X_val, y_val, weights_filename):
    
    try:
        with tf.device(gpu_p40):
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss=LOSS_, 
                metrics=METRICS_)
            
            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
            
            history = model.fit(
                [X_train, X_train], y_train,
                validation_data=([X_val, X_val], y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
            
    except RuntimeError as e:
        print(e)

'''
SCORE
'''
def DeepLab_Score(model, weights_filename, metrics_filename, X_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            score = model.evaluate([X_test, X_test], y_test, batch_size=2, verbose=1)

    except RuntimeError as e:
        print(e)

    # Print and save the test metrics
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])

    with open(metrics_filename, "a") as f:
        f.write(f"\Test Loss: {score[0]}\n")
        f.write(f"\Test Accuracy: {score[1]}\n")
        
'''
PREDICT
'''
def DeepLab_Predict(model, X_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_test, X_test], batch_size=BATCH_SIZE)
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def DeepLab_Display(X_test, y_test, y_pred):

    try:
        with tf.device(gpu_p40):
            fig, axes = plt.subplots(1, 3, figsize=(10, 6))
            n = random.randint(0, len(X_test)-1)
            cmap = plt.get_cmap('tab10', 7)
    
            axes[0].imshow(X_test[n])
            axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
            axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
            axes[0].set_title("RGB")
            axes[1].set_title("Annotation")
            axes[2].set_title("Predicted")
    
            for ax in axes.flatten():
                ax.axis("off")
        
            plt.tight_layout()
            plt.show()
            
    except RuntimeError as e:
        print(e)
'''
METRICS
'''
def DeepLab_Metrics(y_test, y_pred, metrics_filename):

    try:
        with tf.device(gpu_p40):
            y_pred_classes = np.argmax(y_pred, axis=-1)
            y_true_classes = np.argmax(y_test, axis=-1)
    
            num_classes=7

            iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
            pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
            mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
            fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)

            print(f"Mean IoU: {mean_iou}")
            print(f"Pixel accuracy: {pixel_acc}")
            print(f"Mean accuracy: {mean_acc}")
            print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
            with open(metrics_filename, "a") as f:
                f.write("\nIoU Values:\n")
                for i, iou_val in enumerate(iou_values):
                    f.write(f"Class {i}: {iou_val}\n")
                f.write(f"\nMean IoU: {mean_iou}\n")
                f.write(f"Pixel Accuracy: {pixel_acc}\n")
                f.write(f"Mean Accuracy: {mean_acc}\n")
                f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    except RuntimeError as e:
        print(e)

print("Done")
# Out:
# Done

# %%
'''
FILENAMES
'''
exp2_weights_filename = os.path.join(WEIGHTS_PATH, 'tdeeplab_siamese_bl_exp2.h5')
exp2_metrics_filename = os.path.join(METRICS_PATH, 'tdeeplab_siamese_bl_exp2.txt')

print("Done")
# Out:
# Done

# %%
'''
model
'''
try:
    with tf.device(gpu_p40):
        exp2_model = TDeepLab_SiameseBL()     
except RuntimeError as e:
    print(e)

print("Done")
# Out:
# Done

# %%
'''
TRAIN
'''
DeepLab_Train(
    exp2_model, exp2_comb_X_train, exp2_y_train, exp2_comb_X_val, exp2_y_val, exp2_weights_filename)

print("Done")
# Out:
# Epoch 1/1000
# 2023-10-17 23:57:37.835319: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_9/model_7/dropout_12/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-17 23:57:40.760004: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-10-17 23:57:45.155156: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f5a80ebdf10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-17 23:57:45.155192: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla P40, Compute Capability 6.1
# 2023-10-17 23:57:45.195513: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-17 23:57:45.537878: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 0.33090, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 144s - loss: 0.3211 - binary_accuracy: 0.8728 - val_loss: 0.3309 - val_binary_accuracy: 0.8872 - lr: 1.0000e-04 - 144s/epoch - 582ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.33090 to 0.30155, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 112s - loss: 0.2743 - binary_accuracy: 0.8869 - val_loss: 0.3015 - val_binary_accuracy: 0.8923 - lr: 1.0000e-04 - 112s/epoch - 453ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.30155 to 0.26883, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 112s - loss: 0.2581 - binary_accuracy: 0.8930 - val_loss: 0.2688 - val_binary_accuracy: 0.9098 - lr: 1.0000e-04 - 112s/epoch - 454ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.26883
# 247/247 - 110s - loss: 0.2376 - binary_accuracy: 0.9028 - val_loss: 0.2724 - val_binary_accuracy: 0.9134 - lr: 1.0000e-04 - 110s/epoch - 447ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.26883
# 247/247 - 110s - loss: 0.2300 - binary_accuracy: 0.9057 - val_loss: 0.2767 - val_binary_accuracy: 0.9135 - lr: 1.0000e-04 - 110s/epoch - 447ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.26883 to 0.24991, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 112s - loss: 0.2190 - binary_accuracy: 0.9103 - val_loss: 0.2499 - val_binary_accuracy: 0.9101 - lr: 1.0000e-04 - 112s/epoch - 454ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.24991
# 247/247 - 110s - loss: 0.2193 - binary_accuracy: 0.9096 - val_loss: 0.2554 - val_binary_accuracy: 0.9169 - lr: 1.0000e-04 - 110s/epoch - 446ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.24991
# 247/247 - 110s - loss: 0.2078 - binary_accuracy: 0.9141 - val_loss: 0.2658 - val_binary_accuracy: 0.9153 - lr: 1.0000e-04 - 110s/epoch - 446ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 0.24991 to 0.23829, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 112s - loss: 0.2061 - binary_accuracy: 0.9148 - val_loss: 0.2383 - val_binary_accuracy: 0.9177 - lr: 1.0000e-04 - 112s/epoch - 454ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.23829
# 247/247 - 111s - loss: 0.2005 - binary_accuracy: 0.9189 - val_loss: 0.2534 - val_binary_accuracy: 0.9207 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.23829
# 247/247 - 110s - loss: 0.1972 - binary_accuracy: 0.9198 - val_loss: 0.2470 - val_binary_accuracy: 0.9209 - lr: 1.0000e-04 - 110s/epoch - 447ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.23829
# 247/247 - 110s - loss: 0.1956 - binary_accuracy: 0.9204 - val_loss: 0.2483 - val_binary_accuracy: 0.9198 - lr: 1.0000e-04 - 110s/epoch - 447ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss improved from 0.23829 to 0.23055, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 112s - loss: 0.1847 - binary_accuracy: 0.9245 - val_loss: 0.2306 - val_binary_accuracy: 0.9238 - lr: 1.0000e-04 - 112s/epoch - 455ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss improved from 0.23055 to 0.23051, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 112s - loss: 0.1838 - binary_accuracy: 0.9254 - val_loss: 0.2305 - val_binary_accuracy: 0.9193 - lr: 1.0000e-04 - 112s/epoch - 455ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.23051
# 247/247 - 111s - loss: 0.1805 - binary_accuracy: 0.9269 - val_loss: 0.2447 - val_binary_accuracy: 0.9204 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.23051
# 247/247 - 111s - loss: 0.1832 - binary_accuracy: 0.9265 - val_loss: 0.2403 - val_binary_accuracy: 0.9210 - lr: 1.0000e-04 - 111s/epoch - 447ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.23051
# 247/247 - 111s - loss: 0.1803 - binary_accuracy: 0.9272 - val_loss: 0.2476 - val_binary_accuracy: 0.9208 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.23051
# 247/247 - 110s - loss: 0.1702 - binary_accuracy: 0.9318 - val_loss: 0.2417 - val_binary_accuracy: 0.9242 - lr: 1.0000e-04 - 110s/epoch - 447ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.23051
# 247/247 - 111s - loss: 0.1723 - binary_accuracy: 0.9305 - val_loss: 0.2404 - val_binary_accuracy: 0.9231 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.23051
# 247/247 - 111s - loss: 0.1689 - binary_accuracy: 0.9321 - val_loss: 0.2599 - val_binary_accuracy: 0.9272 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss improved from 0.23051 to 0.21115, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_siamese_bl_exp2.h5
# 247/247 - 113s - loss: 0.1705 - binary_accuracy: 0.9313 - val_loss: 0.2111 - val_binary_accuracy: 0.9276 - lr: 1.0000e-04 - 113s/epoch - 456ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1715 - binary_accuracy: 0.9305 - val_loss: 0.2405 - val_binary_accuracy: 0.9281 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1611 - binary_accuracy: 0.9351 - val_loss: 0.2539 - val_binary_accuracy: 0.9253 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1671 - binary_accuracy: 0.9328 - val_loss: 0.2494 - val_binary_accuracy: 0.9234 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1658 - binary_accuracy: 0.9337 - val_loss: 0.2457 - val_binary_accuracy: 0.9272 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1597 - binary_accuracy: 0.9358 - val_loss: 0.2340 - val_binary_accuracy: 0.9278 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1623 - binary_accuracy: 0.9352 - val_loss: 0.2325 - val_binary_accuracy: 0.9284 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1616 - binary_accuracy: 0.9355 - val_loss: 0.2296 - val_binary_accuracy: 0.9306 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1527 - binary_accuracy: 0.9393 - val_loss: 0.2626 - val_binary_accuracy: 0.9260 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1525 - binary_accuracy: 0.9400 - val_loss: 0.2210 - val_binary_accuracy: 0.9301 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1529 - binary_accuracy: 0.9395 - val_loss: 0.2323 - val_binary_accuracy: 0.9281 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1521 - binary_accuracy: 0.9408 - val_loss: 0.2416 - val_binary_accuracy: 0.9266 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1467 - binary_accuracy: 0.9422 - val_loss: 0.2420 - val_binary_accuracy: 0.9282 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1484 - binary_accuracy: 0.9420 - val_loss: 0.2506 - val_binary_accuracy: 0.9263 - lr: 1.0000e-04 - 111s/epoch - 448ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1468 - binary_accuracy: 0.9418 - val_loss: 0.2466 - val_binary_accuracy: 0.9289 - lr: 1.0000e-04 - 111s/epoch - 449ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.21115
# 247/247 - 111s - loss: 0.1454 - binary_accuracy: 0.9425 - val_loss: 0.2460 - val_binary_accuracy: 0.9281 - lr: 1.0000e-04 - 111s/epoch - 449ms/step
# Epoch 36: early stopping
# Done

# %%
'''
SCORE
'''
DeepLab_Score(
    exp2_model, exp2_weights_filename, exp2_metrics_filename, exp2_comb_X_test, exp2_y_test)

print("Done")
# Out:
# 124/124 [==============================] - 20s 159ms/step - loss: 0.2519 - binary_accuracy: 0.9287
# Test loss: 0.2518722414970398
# Test accuracy: 0.9287319779396057
# Done

# %%
'''
PREDICT
'''
exp2_y_pred = DeepLab_Predict(exp2_model, exp2_comb_X_test)

print("Done")
# Out:
# 124/124 [==============================] - 21s 151ms/step
# Done

# %%
'''
DISPLAY RANDOM RESULT
'''
DeepLab_Display(exp2_comb_X_test, exp2_y_test, exp2_y_pred)

# %%
'''
METRICS
'''
DeepLab_Metrics(exp2_y_test, exp2_y_pred, exp2_metrics_filename)
# Out:
# Mean IoU: 0.4461301170694507
# Pixel accuracy: 0.7430853991203924
# Mean accuracy: 0.5820110208131565
# Frequency-Weighted IoU: 0.7172276320234404
