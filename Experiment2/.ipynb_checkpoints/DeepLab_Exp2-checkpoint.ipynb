# %% [markdown]
# # DeepLab

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dropout, Activation, UpSampling2D
from tensorflow.keras.layers import AveragePooling2D, Conv2DTranspose, Concatenate, Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.image import resize, ResizeMethod
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import random
import os
import numpy as np
from numpy import load
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:0'

get_ipython().system('nvidia-smi')

'''
TRAINING DATA
'''
exp2_rgb_X_train = load(TRAIN_DIR + '/exp2_rgb_X_train_dl.npy')
exp2_y_train = load(TRAIN_DIR + '/exp2_y_train_dl.npy')

'''
VALIDATION DATA
'''
exp2_rgb_X_val = load(VAL_DIR + '/exp2_rgb_X_val_dl.npy')
exp2_y_val = load(VAL_DIR + '/exp2_y_val_dl.npy')

'''
TEST DATA
'''
exp2_rgb_X_test = load(TEST_DIR + '/exp2_rgb_X_test_dl.npy')
exp2_y_test = load(TEST_DIR + '/exp2_y_test_dl.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FREQUENCY-WEIGHTED INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', 7)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(7), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# 2023-10-19 00:46:40.075107: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Thu Oct 19 00:46:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   34C    P8    11W / 250W |      0MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Done

# %%
'''
MODEL PARAMS
'''
INPUT_DIMS = (572, 572, 3)

BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

DROPOUT_RATE = 0.5

TRAINABLE_LAYERS = 300

LOSS_ = BinaryCrossentropy()
METRICS_ = [BinaryAccuracy()]

EXP1_FILENAME = "deeplab_exp2_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# 2023-10-15 19:25:01.853696: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:01.859170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:01.859408: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:01.860891: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysf
# Done
# s-bus-pci#L344-L355
# 2023-10-15 19:25:01.861092: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:01.861279: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:02.673015: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:02.673254: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:02.673468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:25:02.673640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 23635 MB memory:  -> device: 0, name: Tesla P40, pci bus id: 0000:05:00.0, compute capability: 6.1

# %% [markdown]
# ### DeepLab Common

# %%
'''
Atrous Spatial Pyramid Pooling
'''
def ASPP(inputs):
    shape = inputs.shape

    y_pool = AveragePooling2D(pool_size=(shape[1], shape[2]), name='average_pooling')(inputs)
    y_pool = Conv2D(filters=256, kernel_size=1, padding='same', use_bias=False)(y_pool)
    y_pool = BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = Activation('relu', name=f'relu_1')(y_pool)
    y_pool = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y_pool)

    y_1 = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(inputs)
    y_1 = BatchNormalization()(y_1)
    y_1 = Activation('relu')(y_1)

    y_6 = Conv2D(filters=256, kernel_size=3, dilation_rate=6, padding='same', use_bias=False)(inputs)
    y_6 = BatchNormalization()(y_6)
    y_6 = Activation('relu')(y_6)

    y_12 = Conv2D(filters=256, kernel_size=3, dilation_rate=12, padding='same', use_bias=False)(inputs)
    y_12 = BatchNormalization()(y_12)
    y_12 = Activation('relu')(y_12)

    y_18 = Conv2D(filters=256, kernel_size=3, dilation_rate=18, padding='same', use_bias=False)(inputs)
    y_18 = BatchNormalization()(y_18)
    y_18 = Activation('relu')(y_18)

    y = Concatenate()([y_pool, y_1, y_6, y_12, y_18])

    y = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    return y

def DeepLab(shape):
    """ Inputs """
    inputs = Input(shape)

    """ Pre-trained ResNet101 """
    base_model = ResNet101(weights='imagenet', include_top=False, input_tensor=inputs)
    
    for layer in base_model.layers[:TRAINABLE_LAYERS]:
        layer.trainable = False
    for layer in base_model.layers[TRAINABLE_LAYERS:]:
        layer.trainable = True

    """ Pre-trained ResNet101 Output """
    image_features = base_model.get_layer('conv4_block23_out').output
    x_a = ASPP(image_features)
    x_a = UpSampling2D((4, 4), interpolation="bilinear")(x_a)

    """ Get low-level features """
    x_b = base_model.get_layer('conv2_block2_out').output
    x_b = Conv2D(filters=48, kernel_size=1, padding='same', use_bias=False)(x_b)
    x_b = BatchNormalization()(x_b)
    x_b = Activation('relu')(x_b)

    """ Spatial Pyramid Pooling (SPP) """
    # Apply different pooling sizes
    pool1 = GlobalAveragePooling2D()(x_a)
    pool2 = GlobalAveragePooling2D()(x_a)
    pool3 = GlobalAveragePooling2D()(x_a)

    # Concatenate pooled features
    spp_features = Concatenate()([pool1, pool2, pool3])

    # Reshape to match x_b's shape
    spp_features = tf.keras.layers.Reshape((1, 1, -1))(spp_features)
    spp_features = UpSampling2D((x_b.shape[1], x_b.shape[2]), interpolation="bilinear")(spp_features)

    x = Concatenate()([spp_features, x_b])

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x) 

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x) 
    x = UpSampling2D((4, 4), interpolation="bilinear")(x)

    """ Outputs """
    x = Conv2D(7, (1, 1), name='output_layer')(x)
    x = Activation('softmax')(x)

    """ Model """
    model = Model(inputs=inputs, outputs=x)
    return model

'''
TRAIN
'''
def DeepLab_Train(model, X_train, y_train, X_val, y_val, weights_filename):
    
    try:
        with tf.device(gpu_p40):
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss=LOSS_, 
                metrics=METRICS_)
            
            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
            
            history = model.fit(
                X_train, y_train,
                validation_data=(X_val, y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
            
    except RuntimeError as e:
        print(e)

'''
SCORE
'''
def DeepLab_Score(model, weights_filename, metrics_filename, X_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            score = model.evaluate(X_test, y_test, batch_size=2, verbose=1)

    except RuntimeError as e:
        print(e)

    # Print and save the test metrics
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])

    with open(metrics_filename, "a") as f:
        f.write(f"\Test Loss: {score[0]}\n")
        f.write(f"\Test Accuracy: {score[1]}\n")
        
'''
PREDICT
'''
def DeepLab_Predict(model, X_rgb_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test], batch_size=BATCH_SIZE)
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def DeepLab_Display(X_rgb_test, y_test, y_pred):

    try:
        with tf.device(gpu_p40):
            fig, axes = plt.subplots(1, 3, figsize=(10, 6))
            n = random.randint(0, len(X_rgb_test)-1)
            cmap = plt.get_cmap('tab10', 7)
    
            axes[0].imshow(X_rgb_test[n])
            axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
            axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
            axes[0].set_title("RGB")
            axes[1].set_title("Annotation")
            axes[2].set_title("Predicted")
    
            for ax in axes.flatten():
                ax.axis("off")
        
            plt.tight_layout()
            plt.show()
            
    except RuntimeError as e:
        print(e)
'''
METRICS
'''
def DeepLab_Metrics(y_test, y_pred, metrics_filename):

    try:
        with tf.device(gpu_p40):
            y_pred_classes = np.argmax(y_pred, axis=-1)
            y_true_classes = np.argmax(y_test, axis=-1)
    
            num_classes=7

            iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
            pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
            mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
            fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)

            print(f"Mean IoU: {mean_iou}")
            print(f"Pixel accuracy: {pixel_acc}")
            print(f"Mean accuracy: {mean_acc}")
            print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
            with open(metrics_filename, "a") as f:
                f.write("\nIoU Values:\n")
                for i, iou_val in enumerate(iou_values):
                    f.write(f"Class {i}: {iou_val}\n")
                f.write(f"\nMean IoU: {mean_iou}\n")
                f.write(f"Pixel Accuracy: {pixel_acc}\n")
                f.write(f"Mean Accuracy: {mean_acc}\n")
                f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    except RuntimeError as e:
        print(e)

print("Done")
# Out:
# Done

# %%
'''
FILENAMES
'''
exp2_weights_filename = os.path.join(WEIGHTS_PATH, 'deeplab_baseline_exp2.h5')
exp2_metrics_filename = os.path.join(METRICS_PATH, 'deeplab_baseline_exp2.txt')

print("Done")
# Out:
# Done

# %%
'''
model
'''
try:
    with tf.device(gpu_p40):
        exp2_model = DeepLab(INPUT_DIMS)         
except RuntimeError as e:
    print(e)

print("Done")
# Out:
# Done

# %%
'''
TRAIN
'''
DeepLab_Train(
    exp2_model, exp2_rgb_X_train, exp2_y_train, exp2_rgb_X_val, exp2_y_val, exp2_weights_filename)

print("Done")
# Out:
# Epoch 1/1000
# 2023-10-15 19:25:13.653725: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-15 19:25:15.094451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-10-15 19:25:17.166917: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fcd67add120 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-15 19:25:17.166956: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla P40, Compute Capability 6.1
# 2023-10-15 19:25:17.171470: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-15 19:25:17.343431: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 0.46382, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 77s - loss: 0.3710 - binary_accuracy: 0.8829 - val_loss: 0.4638 - val_binary_accuracy: 0.8876 - lr: 1.0000e-04 - 77s/epoch - 312ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.46382 to 0.40573, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 58s - loss: 0.2644 - binary_accuracy: 0.9006 - val_loss: 0.4057 - val_binary_accuracy: 0.9003 - lr: 1.0000e-04 - 58s/epoch - 236ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.40573 to 0.33702, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 58s - loss: 0.2368 - binary_accuracy: 0.9105 - val_loss: 0.3370 - val_binary_accuracy: 0.9115 - lr: 1.0000e-04 - 58s/epoch - 235ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.33702
# 247/247 - 57s - loss: 0.2263 - binary_accuracy: 0.9134 - val_loss: 0.3459 - val_binary_accuracy: 0.9030 - lr: 1.0000e-04 - 57s/epoch - 231ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.33702 to 0.30895, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 58s - loss: 0.2148 - binary_accuracy: 0.9185 - val_loss: 0.3090 - val_binary_accuracy: 0.9199 - lr: 1.0000e-04 - 58s/epoch - 237ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.30895 to 0.25374, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 68s - loss: 0.2018 - binary_accuracy: 0.9250 - val_loss: 0.2537 - val_binary_accuracy: 0.9250 - lr: 1.0000e-04 - 68s/epoch - 277ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.25374 to 0.22670, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 58s - loss: 0.1948 - binary_accuracy: 0.9276 - val_loss: 0.2267 - val_binary_accuracy: 0.9287 - lr: 1.0000e-04 - 58s/epoch - 235ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.22670
# 247/247 - 57s - loss: 0.1916 - binary_accuracy: 0.9284 - val_loss: 0.2370 - val_binary_accuracy: 0.9236 - lr: 1.0000e-04 - 57s/epoch - 231ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.22670
# 247/247 - 57s - loss: 0.1818 - binary_accuracy: 0.9336 - val_loss: 0.2310 - val_binary_accuracy: 0.9301 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss improved from 0.22670 to 0.22259, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 58s - loss: 0.1839 - binary_accuracy: 0.9335 - val_loss: 0.2226 - val_binary_accuracy: 0.9286 - lr: 1.0000e-04 - 58s/epoch - 236ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.22259
# 247/247 - 57s - loss: 0.1865 - binary_accuracy: 0.9321 - val_loss: 0.2688 - val_binary_accuracy: 0.9249 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.22259
# 247/247 - 57s - loss: 0.1774 - binary_accuracy: 0.9358 - val_loss: 0.2340 - val_binary_accuracy: 0.9263 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.22259
# 247/247 - 57s - loss: 0.1702 - binary_accuracy: 0.9391 - val_loss: 0.2460 - val_binary_accuracy: 0.9318 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss improved from 0.22259 to 0.20601, saving model to /tf/Notebooks/Iwashita/Output/Weights/deeplab_baseline_exp2.h5
# 247/247 - 58s - loss: 0.1624 - binary_accuracy: 0.9418 - val_loss: 0.2060 - val_binary_accuracy: 0.9302 - lr: 1.0000e-04 - 58s/epoch - 236ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1679 - binary_accuracy: 0.9401 - val_loss: 0.3560 - val_binary_accuracy: 0.9224 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1676 - binary_accuracy: 0.9404 - val_loss: 0.2543 - val_binary_accuracy: 0.9317 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1625 - binary_accuracy: 0.9423 - val_loss: 0.2422 - val_binary_accuracy: 0.9295 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1613 - binary_accuracy: 0.9429 - val_loss: 0.2264 - val_binary_accuracy: 0.9287 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1615 - binary_accuracy: 0.9426 - val_loss: 0.2180 - val_binary_accuracy: 0.9314 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1557 - binary_accuracy: 0.9449 - val_loss: 0.2244 - val_binary_accuracy: 0.9326 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1493 - binary_accuracy: 0.9469 - val_loss: 0.2093 - val_binary_accuracy: 0.9380 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1500 - binary_accuracy: 0.9462 - val_loss: 0.2438 - val_binary_accuracy: 0.9323 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1570 - binary_accuracy: 0.9446 - val_loss: 0.2887 - val_binary_accuracy: 0.9284 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1474 - binary_accuracy: 0.9476 - val_loss: 0.2423 - val_binary_accuracy: 0.9336 - lr: 1.0000e-04 - 57s/epoch - 233ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1420 - binary_accuracy: 0.9491 - val_loss: 0.2323 - val_binary_accuracy: 0.9352 - lr: 1.0000e-04 - 57s/epoch - 233ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1457 - binary_accuracy: 0.9487 - val_loss: 0.2541 - val_binary_accuracy: 0.9301 - lr: 1.0000e-04 - 57s/epoch - 233ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1468 - binary_accuracy: 0.9477 - val_loss: 0.2369 - val_binary_accuracy: 0.9344 - lr: 1.0000e-04 - 57s/epoch - 233ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1391 - binary_accuracy: 0.9508 - val_loss: 0.2177 - val_binary_accuracy: 0.9382 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.20601
# 247/247 - 57s - loss: 0.1413 - binary_accuracy: 0.9497 - val_loss: 0.2501 - val_binary_accuracy: 0.9305 - lr: 1.0000e-04 - 57s/epoch - 232ms/step
# Epoch 29: early stopping
# Done

# %%
'''
SCORE
'''
DeepLab_Score(
    exp2_model, exp2_weights_filename, exp2_metrics_filename, exp2_rgb_X_test, exp2_y_test)

print("Done")
# Out:
# 124/124 [==============================] - 11s 86ms/step - loss: 0.2549 - binary_accuracy: 0.9307
# Test loss: 0.2548826038837433
# Test accuracy: 0.9306755065917969
# Done

# %%
'''
PREDICT
'''
exp2_y_pred = DeepLab_Predict(exp2_model, exp2_rgb_X_test)

print("Done")
# Out:
# 124/124 [==============================] - 11s 79ms/step
# Done

# %%
'''
DISPLAY RANDOM RESULT
'''
DeepLab_Display(exp2_rgb_X_test, exp2_y_test, exp2_y_pred)

# %%
'''
METRICS
'''
DeepLab_Metrics(exp2_y_test, exp2_y_pred, exp2_metrics_filename)
# Out:
# Mean IoU: 0.5042060395683253
# Pixel accuracy: 0.7539606055742137
# Mean accuracy: 0.6468567175410164
# Frequency-Weighted IoU: 0.727273653238405
