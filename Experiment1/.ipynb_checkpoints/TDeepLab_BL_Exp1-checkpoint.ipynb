# %% [markdown]
# # DeepLab

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dropout, Activation, UpSampling2D
from tensorflow.keras.layers import AveragePooling2D, Conv2DTranspose, Concatenate, Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.image import resize, ResizeMethod
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from PIL import Image

import random
import os
import numpy as np
from numpy import load
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:0'

get_ipython().system('nvidia-smi')

'''
TRAINING DATA
'''
exp1_rgb_X_train = load(TRAIN_DIR + '/exp1_rgb_X_train_dl.npy')
exp1_ir_X_train = load(TRAIN_DIR + '/exp1_ir_X_train_dl.npy')
exp1_y_train = load(TRAIN_DIR + '/exp1_y_train_dl.npy')

'''
VALIDATION DATA
'''
exp1_rgb_X_val = load(VAL_DIR + '/exp1_rgb_X_val_dl.npy')
exp1_ir_X_val = load(VAL_DIR + '/exp1_ir_X_val_dl.npy')
exp1_y_val = load(VAL_DIR + '/exp1_y_val_dl.npy')

'''
TEST DATA
'''
exp1_rgb_X_test = load(TEST_DIR + '/exp1_rgb_X_test_dl.npy')
exp1_ir_X_test = load(TEST_DIR + '/exp1_ir_X_test_dl.npy')
exp1_y_test = load(TEST_DIR + '/exp1_y_test_dl.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FREQUENCY-WEIGHTED INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', 7)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(7), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# 2023-10-15 19:03:46.016730: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sun Oct 15 19:03:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   38C    P8    10W / 250W |      0MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Done

# %%
'''
COMBINE RGB/IR IMAGES
'''
def combine_rgb_ir(rgb_images, ir_images):
    combined_images = []
    
    for i in range(len(ir_images)):
        ir = np.dstack([ir_images[i]] * 3)
        rgb = np.asarray(rgb_images[i], dtype=np.uint8)

        comb = ir + rgb
        comb = Image.fromarray(comb)
        comb = comb.resize((572, 572))
        comb = np.asarray(comb)

        combined_images.append(comb)
    
    return np.array(combined_images)

exp1_comb_X_train = combine_rgb_ir(exp1_rgb_X_train, exp1_ir_X_train)
exp1_comb_X_val = combine_rgb_ir(exp1_rgb_X_val, exp1_ir_X_val)
exp1_comb_X_test = combine_rgb_ir(exp1_rgb_X_test, exp1_ir_X_test)

# %%
'''
MODEL PARAMS
'''
INPUT_DIMS = (572, 572, 3)

BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

DROPOUT_RATE = 0.5

TRAINABLE_LAYERS = 300

LOSS_ = BinaryCrossentropy()
METRICS_ = [BinaryAccuracy()]

EXP1_FILENAME = "tdeeplab_bl_exp1_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done
# 2023-10-15 19:03:48.945702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:48.950854: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:48.951099: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:48.952606: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:48.952873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:48.953079: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:49.683203: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:49.683443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:49.683642: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-15 19:03:49.683805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 23635 MB memory:  -> device: 0, name: Tesla P40, pci bus id: 0000:05:00.0, compute capability: 6.1

# %% [markdown]
# ### DeepLab Common

# %%
'''
Atrous Spatial Pyramid Pooling
'''
def ASPP(inputs):
    shape = inputs.shape

    y_pool = AveragePooling2D(pool_size=(shape[1], shape[2]), name='average_pooling')(inputs)
    y_pool = Conv2D(filters=256, kernel_size=1, padding='same', use_bias=False)(y_pool)
    y_pool = BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = Activation('relu', name=f'relu_1')(y_pool)
    y_pool = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y_pool)

    y_1 = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(inputs)
    y_1 = BatchNormalization()(y_1)
    y_1 = Activation('relu')(y_1)

    y_6 = Conv2D(filters=256, kernel_size=3, dilation_rate=6, padding='same', use_bias=False)(inputs)
    y_6 = BatchNormalization()(y_6)
    y_6 = Activation('relu')(y_6)

    y_12 = Conv2D(filters=256, kernel_size=3, dilation_rate=12, padding='same', use_bias=False)(inputs)
    y_12 = BatchNormalization()(y_12)
    y_12 = Activation('relu')(y_12)

    y_18 = Conv2D(filters=256, kernel_size=3, dilation_rate=18, padding='same', use_bias=False)(inputs)
    y_18 = BatchNormalization()(y_18)
    y_18 = Activation('relu')(y_18)

    y = Concatenate()([y_pool, y_1, y_6, y_12, y_18])

    y = Conv2D(filters=256, kernel_size=1, dilation_rate=1, padding='same', use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    return y

def DeepLab(shape):
    """ Inputs """
    inputs = Input(shape)
    
    """ Pre-trained ResNet101 """
    base_model = ResNet101(weights='imagenet', include_top=False, input_tensor=inputs)
    
    for layer in base_model.layers[:TRAINABLE_LAYERS]:
        layer.trainable = False
    for layer in base_model.layers[TRAINABLE_LAYERS:]:
        layer.trainable = True

    """ Pre-trained ResNet101 Output """
    image_features = base_model.get_layer('conv4_block23_out').output
    x_a = ASPP(image_features)
    x_a = UpSampling2D((4, 4), interpolation="bilinear")(x_a)

    """ Get low-level features """
    x_b = base_model.get_layer('conv2_block2_out').output
    x_b = Conv2D(filters=48, kernel_size=1, padding='same', use_bias=False)(x_b)
    x_b = BatchNormalization()(x_b)
    x_b = Activation('relu')(x_b)

    """ Spatial Pyramid Pooling (SPP) """
    # Apply different pooling sizes
    pool1 = GlobalAveragePooling2D()(x_a)
    pool2 = GlobalAveragePooling2D()(x_a)
    pool3 = GlobalAveragePooling2D()(x_a)

    # Concatenate pooled features
    spp_features = Concatenate()([pool1, pool2, pool3])

    # Reshape to match x_b's shape
    spp_features = tf.keras.layers.Reshape((1, 1, -1))(spp_features)
    spp_features = UpSampling2D((x_b.shape[1], x_b.shape[2]), interpolation="bilinear")(spp_features)

    x = Concatenate()([spp_features, x_b])

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)

    x = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(DROPOUT_RATE)(x)
    x = UpSampling2D((4, 4), interpolation="bilinear")(x)

    """ Outputs """
    x = Conv2D(7, (1, 1), name='output_layer')(x)
    x = Activation('softmax')(x)

    """ Model """
    model = Model(inputs=inputs, outputs=x)
    return model

'''
TRAIN
'''
def DeepLab_Train(model, X_train, y_train, X_val, y_val, weights_filename):
    
    try:
        with tf.device(gpu_p40):
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss=LOSS_, 
                metrics=METRICS_)
            
            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
            
            history = model.fit(
                X_train, y_train,
                validation_data=(X_val, y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
            
    except RuntimeError as e:
        print(e)

'''
SCORE
'''
def DeepLab_Score(model, weights_filename, metrics_filename, X_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            score = model.evaluate(X_test, y_test, batch_size=2, verbose=1)

    except RuntimeError as e:
        print(e)

    # Print and save the test metrics
    print("Test loss:", score[0])
    print("Test accuracy:", score[1])

    with open(metrics_filename, "a") as f:
        f.write(f"\Test Loss: {score[0]}\n")
        f.write(f"\Test Accuracy: {score[1]}\n")
        
'''
PREDICT
'''
def DeepLab_Predict(model, X_rgb_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test], batch_size=BATCH_SIZE)
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def DeepLab_Display(X_rgb_test, y_test, y_pred):

    try:
        with tf.device(gpu_p40):
            fig, axes = plt.subplots(1, 3, figsize=(10, 6))
            n = random.randint(0, len(X_rgb_test)-1)
            cmap = plt.get_cmap('tab10', 7)
    
            axes[0].imshow(X_rgb_test[n])
            axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
            axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
            axes[0].set_title("RGB")
            axes[1].set_title("Annotation")
            axes[2].set_title("Predicted")
    
            for ax in axes.flatten():
                ax.axis("off")
        
            plt.tight_layout()
            plt.show()
            
    except RuntimeError as e:
        print(e)
'''
METRICS
'''
def DeepLab_Metrics(y_test, y_pred, metrics_filename):

    try:
        with tf.device(gpu_p40):
            y_pred_classes = np.argmax(y_pred, axis=-1)
            y_true_classes = np.argmax(y_test, axis=-1)
    
            num_classes=7

            iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
            pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
            mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
            fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)

            print(f"Mean IoU: {mean_iou}")
            print(f"Pixel accuracy: {pixel_acc}")
            print(f"Mean accuracy: {mean_acc}")
            print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
            with open(metrics_filename, "a") as f:
                f.write("\nIoU Values:\n")
                for i, iou_val in enumerate(iou_values):
                    f.write(f"Class {i}: {iou_val}\n")
                f.write(f"\nMean IoU: {mean_iou}\n")
                f.write(f"Pixel Accuracy: {pixel_acc}\n")
                f.write(f"Mean Accuracy: {mean_acc}\n")
                f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    except RuntimeError as e:
        print(e)

print("Done")
# Out:
# Done

# %%
'''
FILENAMES
'''
exp1_weights_filename = os.path.join(WEIGHTS_PATH, 'tdeeplab_bl_exp1.h5')
exp1_metrics_filename = os.path.join(METRICS_PATH, 'tdeeplab_bl_exp1.txt')

print("Done")
# Out:
# Done

# %%
'''
model
'''
try:
    with tf.device(gpu_p40):
        exp1_model = DeepLab(INPUT_DIMS)         
except RuntimeError as e:
    print(e)

print("Done")
# Out:
# Done

# %%
'''
TRAIN
'''
DeepLab_Train(
    exp1_model, exp1_comb_X_train, exp1_y_train, exp1_comb_X_val, exp1_y_val, exp1_weights_filename)

print("Done")
# Out:
# Epoch 1/1000
# 2023-10-15 19:03:57.989133: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-15 19:03:59.435087: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-10-15 19:04:01.431494: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f5daa40b500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-15 19:04:01.431535: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla P40, Compute Capability 6.1
# 2023-10-15 19:04:01.436810: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-15 19:04:01.590275: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 0.42427, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 24s - loss: 0.7291 - binary_accuracy: 0.8504 - val_loss: 0.4243 - val_binary_accuracy: 0.8726 - lr: 1.0000e-04 - 24s/epoch - 868ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.42427
# 28/28 - 6s - loss: 0.4779 - binary_accuracy: 0.8672 - val_loss: 0.4524 - val_binary_accuracy: 0.8448 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 0.42427 to 0.38467, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 8s - loss: 0.4082 - binary_accuracy: 0.8736 - val_loss: 0.3847 - val_binary_accuracy: 0.8460 - lr: 1.0000e-04 - 8s/epoch - 274ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.38467
# 28/28 - 6s - loss: 0.3475 - binary_accuracy: 0.8935 - val_loss: 0.4599 - val_binary_accuracy: 0.8498 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.38467
# 28/28 - 6s - loss: 0.3215 - binary_accuracy: 0.8996 - val_loss: 0.4442 - val_binary_accuracy: 0.8645 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.38467 to 0.30856, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.3362 - binary_accuracy: 0.8866 - val_loss: 0.3086 - val_binary_accuracy: 0.8912 - lr: 1.0000e-04 - 7s/epoch - 259ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.30856
# 28/28 - 6s - loss: 0.2926 - binary_accuracy: 0.9043 - val_loss: 0.3251 - val_binary_accuracy: 0.8942 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.30856
# 28/28 - 6s - loss: 0.2865 - binary_accuracy: 0.9028 - val_loss: 0.3118 - val_binary_accuracy: 0.8951 - lr: 1.0000e-04 - 6s/epoch - 223ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 0.30856 to 0.28585, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.2959 - binary_accuracy: 0.8934 - val_loss: 0.2858 - val_binary_accuracy: 0.8968 - lr: 1.0000e-04 - 7s/epoch - 262ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.28585
# 28/28 - 6s - loss: 0.2905 - binary_accuracy: 0.8965 - val_loss: 0.3068 - val_binary_accuracy: 0.8961 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.28585
# 28/28 - 6s - loss: 0.2770 - binary_accuracy: 0.9011 - val_loss: 0.3567 - val_binary_accuracy: 0.8996 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss improved from 0.28585 to 0.25988, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.2577 - binary_accuracy: 0.9115 - val_loss: 0.2599 - val_binary_accuracy: 0.9173 - lr: 1.0000e-04 - 7s/epoch - 264ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss improved from 0.25988 to 0.25936, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.2676 - binary_accuracy: 0.9072 - val_loss: 0.2594 - val_binary_accuracy: 0.9139 - lr: 1.0000e-04 - 7s/epoch - 263ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2716 - binary_accuracy: 0.8991 - val_loss: 0.2825 - val_binary_accuracy: 0.9075 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2608 - binary_accuracy: 0.9036 - val_loss: 0.2745 - val_binary_accuracy: 0.9085 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2515 - binary_accuracy: 0.9078 - val_loss: 0.3034 - val_binary_accuracy: 0.9009 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2447 - binary_accuracy: 0.9123 - val_loss: 0.2908 - val_binary_accuracy: 0.9067 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2462 - binary_accuracy: 0.9099 - val_loss: 0.3376 - val_binary_accuracy: 0.8944 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2472 - binary_accuracy: 0.9083 - val_loss: 0.3651 - val_binary_accuracy: 0.9033 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2228 - binary_accuracy: 0.9226 - val_loss: 0.3881 - val_binary_accuracy: 0.8930 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2236 - binary_accuracy: 0.9229 - val_loss: 0.2954 - val_binary_accuracy: 0.9017 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2220 - binary_accuracy: 0.9218 - val_loss: 0.3103 - val_binary_accuracy: 0.9063 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.25936
# 28/28 - 6s - loss: 0.2172 - binary_accuracy: 0.9236 - val_loss: 0.3549 - val_binary_accuracy: 0.9033 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss improved from 0.25936 to 0.25697, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.2203 - binary_accuracy: 0.9213 - val_loss: 0.2570 - val_binary_accuracy: 0.9125 - lr: 1.0000e-04 - 7s/epoch - 259ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.25697
# 28/28 - 6s - loss: 0.2305 - binary_accuracy: 0.9118 - val_loss: 0.3695 - val_binary_accuracy: 0.8981 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss improved from 0.25697 to 0.25584, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.2098 - binary_accuracy: 0.9269 - val_loss: 0.2558 - val_binary_accuracy: 0.9145 - lr: 1.0000e-04 - 7s/epoch - 259ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss improved from 0.25584 to 0.23612, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.2150 - binary_accuracy: 0.9235 - val_loss: 0.2361 - val_binary_accuracy: 0.9214 - lr: 1.0000e-04 - 7s/epoch - 259ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.23612
# 28/28 - 6s - loss: 0.2155 - binary_accuracy: 0.9223 - val_loss: 0.2421 - val_binary_accuracy: 0.9181 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 0.23612
# 28/28 - 6s - loss: 0.2046 - binary_accuracy: 0.9249 - val_loss: 0.3085 - val_binary_accuracy: 0.8998 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 0.23612
# 28/28 - 6s - loss: 0.2015 - binary_accuracy: 0.9302 - val_loss: 0.3862 - val_binary_accuracy: 0.8904 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 0.23612
# 28/28 - 6s - loss: 0.1968 - binary_accuracy: 0.9301 - val_loss: 0.3249 - val_binary_accuracy: 0.9047 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 0.23612
# 28/28 - 6s - loss: 0.1914 - binary_accuracy: 0.9329 - val_loss: 0.2567 - val_binary_accuracy: 0.9092 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 0.23612
# 28/28 - 6s - loss: 0.1915 - binary_accuracy: 0.9340 - val_loss: 0.2438 - val_binary_accuracy: 0.9125 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss improved from 0.23612 to 0.23262, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.1930 - binary_accuracy: 0.9340 - val_loss: 0.2326 - val_binary_accuracy: 0.9236 - lr: 1.0000e-04 - 7s/epoch - 259ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss improved from 0.23262 to 0.21471, saving model to /tf/Notebooks/Iwashita/Output/Weights/tdeeplab_bl_exp1.h5
# 28/28 - 7s - loss: 0.1815 - binary_accuracy: 0.9372 - val_loss: 0.2147 - val_binary_accuracy: 0.9248 - lr: 1.0000e-04 - 7s/epoch - 266ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1790 - binary_accuracy: 0.9372 - val_loss: 0.2765 - val_binary_accuracy: 0.9125 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1921 - binary_accuracy: 0.9338 - val_loss: 0.2451 - val_binary_accuracy: 0.9207 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.2116 - binary_accuracy: 0.9253 - val_loss: 0.2797 - val_binary_accuracy: 0.9096 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1935 - binary_accuracy: 0.9324 - val_loss: 0.2684 - val_binary_accuracy: 0.9217 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1853 - binary_accuracy: 0.9364 - val_loss: 0.2408 - val_binary_accuracy: 0.9174 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1736 - binary_accuracy: 0.9423 - val_loss: 0.2494 - val_binary_accuracy: 0.9202 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1818 - binary_accuracy: 0.9374 - val_loss: 0.2561 - val_binary_accuracy: 0.9195 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1872 - binary_accuracy: 0.9355 - val_loss: 0.2765 - val_binary_accuracy: 0.9087 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.2052 - binary_accuracy: 0.9273 - val_loss: 0.2803 - val_binary_accuracy: 0.9165 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1768 - binary_accuracy: 0.9390 - val_loss: 0.2639 - val_binary_accuracy: 0.9279 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1816 - binary_accuracy: 0.9374 - val_loss: 0.2885 - val_binary_accuracy: 0.9173 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1972 - binary_accuracy: 0.9294 - val_loss: 0.3086 - val_binary_accuracy: 0.9185 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1842 - binary_accuracy: 0.9345 - val_loss: 0.4286 - val_binary_accuracy: 0.9110 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1896 - binary_accuracy: 0.9333 - val_loss: 0.3765 - val_binary_accuracy: 0.9078 - lr: 1.0000e-04 - 6s/epoch - 224ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 0.21471
# 28/28 - 6s - loss: 0.1746 - binary_accuracy: 0.9371 - val_loss: 0.2616 - val_binary_accuracy: 0.9218 - lr: 1.0000e-04 - 6s/epoch - 225ms/step
# Epoch 50: early stopping
# Done

# %%
'''
SCORE
'''
DeepLab_Score(
    exp1_model, exp1_weights_filename, exp1_metrics_filename, exp1_comb_X_test, exp1_y_test)

print("Done")
# Out:
# 14/14 [==============================] - 1s 79ms/step - loss: 0.2729 - binary_accuracy: 0.9117
# Test loss: 0.27286845445632935
# Test accuracy: 0.9116527438163757
# Done

# %%
'''
PREDICT
'''
exp1_y_pred = DeepLab_Predict(exp1_model, exp1_comb_X_test)

print("Done")
# Out:
# 14/14 [==============================] - 2s 74ms/step
# Done

# %%
'''
DISPLAY RANDOM RESULT
'''
DeepLab_Display(exp1_comb_X_test, exp1_y_test, exp1_y_pred)

# %%
'''
METRICS
'''
DeepLab_Metrics(exp1_y_test, exp1_y_pred, exp1_metrics_filename)
# Out:
# Mean IoU: 0.3654790652178768
# Pixel accuracy: 0.6839967287956799
# Mean accuracy: 0.47511828610425966
# Frequency-Weighted IoU: 0.6266905005061272
